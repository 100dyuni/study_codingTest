# %% [markdown]
# 모험가 길드
#
# 공포도가 X인 모험가는 반드시 X명 이상으로 구성해야 여행을 떠날 수 있다.
#
# 입력조건<br>
# 첫째 줄에 모험가의 수 N이 주어집니다.<br>
# 둘째 줄에 각 모험가의 공포도의 값을 N이하의 자연수로 주어지며, 각 자연수는 공백으로 구분합니다.
#
# 출력조건<br>
# 여행을 떠날 수 있는 그룹 수의 최댓값을 출력합니다.
#
# 입력예시<br>
# 5<br>
# 2 3 1 2 2
#
# 출력예시<br>
# 2

# %%
N = int(input())
gongpo_list=list(map(int,input().split()))

gongpo_list.sort()

count=0
temp = []

for i in range(N):
  temp.append(gongpo_list[i])
  if(max(temp)==len(temp)):
    temp = []
    count +=1

print(count)
# Out:
# 5
# 2 3 1 2 2
# 나가
# 나가
# 5
# [1, 2, 2, 2, 3]
# 2

# %%
n = int(input())
data = list(map(int,input().split()))
data.sort()

result = 0 #총 그룹수
count = 0 #현재 그룹에 포함된 모험가의 수 

for i in data:
  count +=1
  if count >=i:
    result +=1
    count = 0
print(result)
# Out:
# 5
# 2 3 1 2 2
# 2

# %% [markdown]
# 곱하기 혹은 더하기
#
# 0부터 9까지 이루어진 문자열 S가 주어졋을때 곱하기 더하기 연산을 하여 가장 큰수를 만들어내라
#
# 입력조건<br>
# 첫째 줄에 여러 개의 숫자로 구성된 하나의 문자열 S가 주어진다<br>
#
# 출력조건<br>
# 첫째 줄에 만들어질 수 잇는 가장 큰 수를 출력합니다.
#
# 입력예시<br>
# 02984<br>
#
# 출력예시 <br>
# 576

# %%
S = str(input())
result = 0
numList = []
for i in range(len(S)):
  numList.append(int(S[i:i+1]))
  
numList.sort()

for j in numList:
  if result ==0:
    result +=j
  else:
    result *=j

print(S)
print(numList)
print(result)
# Out:
# 567
# 567
# [5, 6, 7]
# 210

# %%
data = input()

result = int(data[0])
for i in range(1,len(data)):
  num = int(data[i])
  if result <=1 or num <=1:
    result += num
  else:
    result *= num

print(result)
# Out:
# 02984
# 576

# %% [markdown]
# 문자열 뒤집기
#
# 0과 1로만 이루어진 문자열 S를 받는다.<br>
# 문자열 S에 잇는 모든 숫자를 전부 같게 만들려고 한다. 할수있는 행동은 연속된 하나 이상의 숫자를 잡고 모두 뒤집는게 가능<br>
# 예시 S=0001100일때, 연속된 4,5번 을 한번에 뒤집으면 모든 숫자가 0이 되므로 최소 출력값은 1이다
#
# 입력조건<br>
# 첫째 줄에 0과 1로만 이루어진 문자열 S가 주어집니다.
#
# 출력조건<br>
# 첫째 줄에 다솜이가 해야 하는 행동의 최소 횟수를 출력합니다.

# %%
data = input()
temp=int(data[0])
count0=0
count1=0

if temp==0:
  count0 =1
else:
  count1 =1

for i in range(1,len(data)):
  if temp == int(data[i]):
    continue
  else:
    temp = int(data[i])
    if int(data[i])==0:
      count0 +=1
    else:
      count1 +=1

print(min(count0,count1))
# Out:
# 11001110
# 2

# %%
data =input()
count0 = 0
count1 = 0

if data[0] =='1':
  count0 +=1
else:
  count1 +=1

for i in range(len(data) -1):
  if data[i] != data[i+1]:
    if data[i+1] =='1':
      count0 +=1
    else:
      count1 +=1

print(min(count1,count0))
# Out:
# 11001110
# 2

# %% [markdown]
# 만들 수 없는 금액
#
# 동네 편의점의 주인인 동빈이는 N개의 도저을 가직욌다.이때 동전을 이용하여 만들 수 없는 양의 정수 금액 중 최솟값을 구하는 프로그램을 작성하시오.
#
# 입력조건<br>
# 첫째 줄에는 동전의 개수를 나타내는 양의정수 N이 주어집니다.<br>
# 둘째 줄에는 각 동전의 화폐 단위를 나타내는 N개의 자연수가 주어지며, 각 자연수는 공백으로 구분합니다.
#
# 출력조건<br>
# 첫재 줄에 주어진 동전들로 만들 수 없는 양의 정수 금액 중 최솟값을 출력합니다.
#
# 입력예시<br>
# 5<br>
# 3 2 1 1 9

# %%
N=int(input())
coinList = list(map(int,input().split()))
coinList.sort(reverse=True)
target = 0
temp =0

while True:
  if(temp != 0):
    print("target",target)
    break
  target +=1
  temp=target

  for i in coinList:
    if temp-i ==0:
      temp -=i
      break
    elif temp-i <0:
      continue
    else:
      temp -=i
# Out:
# 5
# 3 2 1 1 9
# target 8

# %%
n = int(input())
data = list(map(int,input().split()))
data.sort()

target =1 
for x in data:
  if target < x:
    break
  target +=x

print(target)
# Out:
# 5
# 3 2 1 1 9
# 8

# %% [markdown]
# 볼링공 고르기
#
# A B 두 사람이 볼링을 침, 두 사람은 서로 다른 무게의 볼링공을 고르게함
# 볼링공은 총 N개가 있으며, 무게 최대치는 M
#
# 입력조건<br>
# 첫째줄에 볼링공의 개수 N, 공의 최대 무게 M이 공백으로 구분되어 각각 자연수 형태로 주어짐<br>
# 둘째 줄에 각 볼링공의 무게 K가 공백으로 구분되어 순서대로 자연수 형태로 주어짐
#
# 출력조건<br>
# 첫째 줄에 두 사람이 볼링공을 고르는 경우의 수를 출력합니다.
#
# 입력예시<br>
# 5 3<br>
# 1 3 2 3 2
#
# 출력예시<br>
# 8

# %%
N, M = map(int,input().split())
gongList = list(map(int,input().split()))
count = 0

for i in range(len(gongList)):
  temp = gongList[i]
  for j in range(i,len(gongList)):
    #print(temp,gongList[j])
    if(temp!=gongList[j]):
      count +=1



print(gongList)
print(count)
# Out:
# 8 5
# 1 5 4 3 2 4 5 2
# [1, 5, 4, 3, 2, 4, 5, 2]
# 25

# %%
n,m = map(int,input().split())

data = list(map(int,input().split()))
#1부터 10까지의 무게를 담을 수 있는 리스트
array = [0]*11

for x in data:
  #각 무게에 해당하는 볼링공의 개수 카운트
  array[x] +=1

result = 0

for i in range(1,m+1):
  n -=array[i]
  result += array[i]*n

print(result)
# Out:
# 5 3
# 1 2 3 2 3
# 8

# %% [markdown]
# 무지의 먹방 라이브
#
# 회전판에 먹어야할 음식 N개, 1번부터 N번까지 번호 생성
#
# 1번부터 먹기시작 회전판은 번호가 증가하는 순서대로 음식을 무지 앞으로 가져다 높음,
# 마지막 번호의 음시을 섭취한 후에는 회전판에 의해 다시 1번 음시이 무지 앞으로옴,
# 무지는 음식 하나를 1초동안 섭취한 후 남은 음식은 그대로두고 다음 음식을 섭취,
# 회전판이 다음 음식을 무지앞으로 가져오는데 걸리는 시간은 없음
#
# 각음식을 모두 먹는데 필요한 시간 food_times, 네트워크 장애가 발생한 시간 k,
# 몇번음식부터 다시 섭취하면 되는지 리턴하는 함수를 완성
#
# 더 섭취하 음식이 없다면 -1 반환

# %%
n,k =map(int,input().split())

food_times = list(map(int,input().split()))
totTime = 0
tempn =0

for i in food_times:
  totTime +=i

for j in range(0,totTime):
  if j+1 ==k:
    print(tempn)
    break
  if food_times[tempn] ==0:
    tempn +=1

  if tempn >n:
    tempn =0

  if food_times[tempn] !=0:
    food_times[tempn] -=1
# Out:
# 3 5
# 3 1 2
# 1

# %%
##프로그래머스 사이트에서 테스트해야 정상 동작한다고 함.
import heapq

def solution(food_times,k):
  #전체 음식을 먹는 시간보다 K가 크거나 같다면 -1
  if sum(food_times) <=k:
    return -1

  #시간이 작은 음식부터 빼야 하므로 우선순위 큐를 이용
  q=[]
  for i in range(len(food_times)):
    heapq.heappush(q,(food_times[i],i+1))

  sum_value = 0 #먹기 위해 사용한 시간
  previous = 0 #직전에 다 먹은 음식 시간
  length = len(food_times) #남은 음식의 개수

  #sum_value +(현재의 음식 시간 -이전 음식 시간) * 현재 음식 개수와 K비교
  while sum_value + ((q[0][0]- previous) * length) <=k:
    now = heapq.heappop(q)[0]
    sum_value += (now - previous)* length
    length -=1  #다 먹음 음식 제외
    previous = now #이전 음식 시간 재설정

    #남은 음식 중에서 몇 번째 음식인지 확인하여 출력
  result = sorted(q,key=lambda x:x[1])
  return result[(k - sum_value)%length][1]
